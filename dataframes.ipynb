# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

from pydataset import data

# %%
#Copy the code from the lesson to create a dataframe full of student grades.

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
# Create a column named passing_english that indicates whether each student has a passing grade in english.
df['passing_english'] = df.english >= 70

# %%
# Sort the english grades by the passing_english column. How are duplicates handled?
df.sort_values(by='passing_english')
#letters_series[letters_series.isin(vowels)].value_counts().sum()
#df[df.sort_values(by='english')] = df.english > 70.value_counts().sum()
# Out:
#        name  math  english  reading  passing_english  student average
# 6    Thomas    82       64       81            False        75.666667
# 7     Marie    93       63       90            False        82.000000
# 8    Albert    92       62       87            False        80.333333
# 11     Alan    92       62       72            False        75.333333
# 0     Sally    62       85       80             True        75.666667
# 1      Jane    88       79       67             True        78.000000
# 2     Suzie    94       74       95             True        87.666667
# 3     Billy    98       96       88             True        94.000000
# 4       Ada    77       92       98             True        89.000000
# 5      John    79       76       93             True        82.666667
# 9   Richard    69       80       94             True        81.000000
# 10    Isaac    92       99       93             True        94.666667

# %% [markdown]
#  Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
df.sort_values(by=['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_english  student average
# 11     Alan    92       62       72            False        75.333333
# 8    Albert    92       62       87            False        80.333333
# 7     Marie    93       63       90            False        82.000000
# 6    Thomas    82       64       81            False        75.666667
# 4       Ada    77       92       98             True        89.000000
# 3     Billy    98       96       88             True        94.000000
# 10    Isaac    92       99       93             True        94.666667
# 1      Jane    88       79       67             True        78.000000
# 5      John    79       76       93             True        82.666667
# 9   Richard    69       80       94             True        81.000000
# 0     Sally    62       85       80             True        75.666667
# 2     Suzie    94       74       95             True        87.666667

# %% [markdown]
# Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
df.sort_values(by=['passing_english', 'english'])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
df['student average'] = (df.math + df.english + df.reading) / 3
df
# Out:
#        name  math  english  reading  passing_english  student average
# 0     Sally    62       85       80             True        75.666667
# 1      Jane    88       79       67             True        78.000000
# 2     Suzie    94       74       95             True        87.666667
# 3     Billy    98       96       88             True        94.000000
# 4       Ada    77       92       98             True        89.000000
# 5      John    79       76       93             True        82.666667
# 6    Thomas    82       64       81            False        75.666667
# 7     Marie    93       63       90            False        82.000000
# 8    Albert    92       62       87            False        80.333333
# 9   Richard    69       80       94             True        81.000000
# 10    Isaac    92       99       93             True        94.666667
# 11     Alan    92       62       72            False        75.333333

# %% [markdown]
# Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
from pydataset import data
mpg = data('mpg')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# How many rows and columns are there?
# What are the data types of each column?
# Summarize the dataframe with .info and .describe
# Rename the cty column to city.
# Rename the hwy column to highway.
# Do any cars have better city mileage than highway mileage?
# Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.
# Which car (or cars) has the highest mileage difference?
# Which compact class car has the lowest highway mileage? The best?
# Create a column named average_mileage that is the mean of the city and highway mileage.
# Which dodge car has the best average mileage? The worst?

# %%
# How many rows and columns
mpg.shape
# Out:
# (234, 11)

# %%
#  what are the data types for each column
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %%
#Summarize the dataframe with .info and .describe
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
# rename columns cty and hwy.
mpg = mpg.rename(columns = {'cty' : 'city'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ...

# %%
mpg = mpg.rename(columns = {'hwy' : 'highway'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %%
#Do any cars have better city mileage than highway mileage?
mpg[mpg.city > mpg.highway]
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, highway, fl, class]
# Index: []

# %%
#Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.
mpg['milage_difference'] = mpg.highway - mpg.city
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  milage_difference
# ...

# %%
#Which car (or cars) has the highest mileage difference?
mpg.sort_values(by='milage_difference',ascending=False).head(5)
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
# 1           audi          a4    1.8  1999    4  auto(l5)   f    18       29
# 229   volkswagen      passat    1.8  1999    4  auto(l5)   f    18       29
# 36     chevrolet      malibu    3.5  2008    6  auto(l4)   f    18       29
#
#     fl       class  milage_difference
# 107  c  subcompact                 12
# 223  d  subcompact                 12
# 1    p     compact                 11
# 229  p     midsize                 11
# 36   r     midsize                 11

# %%
mpg.milage_difference.max()
# Out:
# 12

# %%
#df[df.english > 90].sort_values(by='english').head(1).name
#mpg.milage_difference.max().head(5).manufacturer

# %%
# Which compact class car has the lowest highway mileage? The best?
mpg[mpg["class"] == 'compact'].sort_values(by='highway', ascending=False)
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  city  \
# 213   volkswagen         jetta    1.9  1999    4  manual(m5)   f    33
# 197       toyota       corolla    1.8  2008    4  manual(m5)   f    28
# 196       toyota       corolla    1.8  1999    4  manual(m5)   f    26
# 198       toyota       corolla    1.8  2008    4    auto(l4)   f    26
# 195       toyota       corolla    1.8  1999    4    auto(l4)   f    24
# 189       toyota  camry solara    2.4  2008    4  manual(m5)   f    21
# 3           audi            a4    2.0  2008    4  manual(m6)   f    20
# 190       toyota  camry solara    2.4  2008    4    auto(s5)   f    22
# 4           audi            a4    2.0  2008    4    auto(av)   f    21
# 194       toyota       corolla    1.8  1999    4    auto(l3)   f    24
# 208   volkswagen           gti    2.0  1999    4  manual(m5)   f    21
# 211   volkswagen           gti    2.0  2008    4    auto(s6)   f    22
# ...

# %%
mpg[mpg["class"] == 'compact'].sort_values(by='highway', ascending=False).min()
# Out:
# manufacturer             audi
# model                      a4
# displ                     1.8
# year                     1999
# cyl                         4
# trans                auto(av)
# drv                         4
# city                       15
# highway                    23
# fl                          d
# class                 compact
# milage_difference           5
# dtype: object

# %%
mpg[mpg["class"] == 'compact'].sort_values(by='highway', ascending=False).max()
# Out:
# manufacturer         volkswagen
# model                     jetta
# displ                       3.3
# year                       2008
# cyl                           6
# trans                manual(m6)
# drv                           f
# city                         33
# highway                      44
# fl                            r
# class                   compact
# milage_difference            11
# dtype: object

# %%
# Create a column named average_mileage that is the mean of the city and highway mileage.
mpg['average_mileage'] = (mpg.highway + mpg.city) / 2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
# Which dodge car has the best average mileage? The worst?
mpg[mpg["manufacturer"] == 'dodge'].sort_values(by='average_mileage', ascending=False)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 38        dodge          caravan 2wd    2.4  1999    4    auto(l3)   f    18
# 42        dodge          caravan 2wd    3.3  2008    6    auto(l4)   f    17
# 43        dodge          caravan 2wd    3.3  2008    6    auto(l4)   f    17
# 39        dodge          caravan 2wd    3.0  1999    6    auto(l4)   f    17
# 47        dodge          caravan 2wd    3.8  2008    6    auto(l6)   f    16
# 48        dodge          caravan 2wd    4.0  2008    6    auto(l6)   f    16
# 40        dodge          caravan 2wd    3.3  1999    6    auto(l4)   f    16
# 41        dodge          caravan 2wd    3.3  1999    6    auto(l4)   f    16
# 45        dodge          caravan 2wd    3.8  1999    6    auto(l4)   f    15
# 46        dodge          caravan 2wd    3.8  1999    6    auto(l4)   f    15
# 49        dodge    dakota pickup 4wd    3.7  2008    6  manual(m6)   4    15
# ...

# %%
mpg[mpg["manufacturer"] == 'dodge'].sort_values(by='average_mileage', ascending=False).nlargest(1,'average_mileage',keep='all')
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl    class  milage_difference  average_mileage
# 38  r  minivan                  6             21.0

# %%
mpg[mpg["manufacturer"] == 'dodge'].sort_values(by='average_mileage', ascending=False).nsmallest(1,'average_mileage',keep='all')
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl   class  milage_difference  average_mileage
# 66       12  e  pickup                  3             10.5
# 60       12  e     suv                  3             10.5
# 55       12  e  pickup                  3             10.5
# 70       12  e  pickup                  3             10.5

# %% [markdown]
# Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:
# How many rows and columns are there?
# What are the data types?
# Summarize the dataframe with .info and .describe
# What is the the weight of the fastest animal?
# What is the overal percentage of specials?
# How many animals are hoppers that are above the median speed? What percentage is this?

# %%
mammals = data('Mammals')

# %%
mammals
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %%
#coloumns and rows in dataset
mammals.shape
# Out:
# (107, 4)

# %%
# datatypes for dataset
mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
# .info for dataset
mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
# .describe for dataset
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %%
# What is the the weight of the fastest animal?
mammals.sort_values(by='speed', ascending=False).head()
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False
# 39    37.0  105.0    False     False
# 35    50.0  100.0    False     False
# 41    34.0   97.0    False     False
# 42    30.0   97.0    False     False

# %%
# What is the overal percentage of specials?
special_mammals = mammals["specials"] == True
nonspecial_mammals = mammals["specials"] == False

total_mammals = ((mammals["specials"] == True ) + (mammals["specials"] == False))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [47], in <cell line: 7>()
#       3 nonspecial_mammals = mammals["specials"] == False
#       5 total_mammals = ((mammals["specials"] == True ) + (mammals["specials"] == False))
# ----> 7 special_mammals / total_mammals
#
# File /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:124, in OpsMixin.__truediv__(self, other)
#     122 @unpack_zerodim_and_defer("__truediv__")
#     123 def __truediv__(self, other):
# --> 124     return self._arith_method(other, operator.truediv)
#
# ...
